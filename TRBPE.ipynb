# %%
import os
import tokenizer
import pandas as pd
import re, collections
import pickle
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
fname = 'datasets/all_news.txt'

# %%
def get_vocab(filename):
    vocab = collections.defaultdict(int)
    with open(filename, 'r', encoding='utf-8') as fhand:
        for line in fhand:
            words = line.strip().split()
            for word in words:
                vocab[' '.join(list(word)) + ' </w>'] += 1
    return vocab

def get_stats(vocab):
    pairs = collections.defaultdict(int)
    for word, freq in vocab.items():
        symbols = word.split()
        for i in range(len(symbols)-1):
            pairs[symbols[i],symbols[i+1]] += freq
    return pairs

def merge_vocab(pair, v_in):
    v_out = {}
    bigram = re.escape(' '.join(pair))
    p = re.compile(r'(?<!\S)' + bigram + r'(?!\S)')
    for word in v_in:
        w_out = p.sub(''.join(pair), word)
        v_out[w_out] = v_in[word]
    return v_out

def get_tokens(vocab):
    tokens = collections.defaultdict(int)
    for word, freq in vocab.items():
        word_tokens = word.split()
        for token in word_tokens:
            tokens[token] += freq
    return tokens

# %%
pickle_in = open("tokens7000.pkl","rb")
tokens = pickle.load(pickle_in)
pickle_in = open("vocabu7000.pkl","rb")
vocab = pickle.load(pickle_in)

# %%
#vocab = get_vocab(fname)

print('==========')
print('Tokens Before BPE')
#tokens = get_tokens(vocab)
print('Tokens: {}'.format(tokens))
print('Number of tokens: {}'.format(len(tokens)))
print('==========')

num_merges = 5055
for i in range(num_merges):
    pairs = get_stats(vocab)
    
    if not pairs:
        break
    best = max(pairs,key=pairs.get)
    vocab = merge_vocab(best, vocab)
    print('Iter: {}'.format(i))
    print('Best pair: {}'.format(best))
    tokens = get_tokens(vocab)
    print('Tokens lenght: {}'.format(len(tokens)))
    print('=' * 10)
# Out:
# ==========
# Tokens Before BPE
# Tokens: defaultdict(<class 'int'>, {'"': 2, 'Yatırım</w>': 943, 'bank': 4812, 'ası': 5378, ':</w>': 44848, 'D': 56288, 'olar': 2673, '/': 16840, 'TL</w>': 7883, 'üçüncü</w>': 2151, 'ç': 46129, 'ey': 23545, 'rek': 2185, 'te</w>': 20958, '8.': 1189, '90': 2153, '’ı</w>': 3606, 'gör': 19023, 'ecek</w>': 14306, '04': 1173, '03': 1896, '/2019</w>': 479, '14': 12241, ':33</w>': 1207, 'Tor': 1589, 'on': 30624, 'to</w>': 3383, 'merkezli</w>': 1346, 'yatırım</w>': 4566, 'ası</w>': 31147, 'T': 57068, 'D</w>': 2332, 'S': 88322, 'ec': 12365, 'ur': 21321, 'iti': 3326, 'es,</w>': 2057, 'lir': 3085, 'anın</w>': 16472, 'dolar</w>': 6318, 'karşısında</w>': 3933, 'yüzde</w>': 30489, '40</w>': 4694, 'kayıp</w>': 1026, 'yaşay': 2086, 'arak</w>': 18526, 'eceğini</w>': 8198, 'iddia</w>': 4922, 'etti.</w>': 22161, 'Fotoğraf': 1607, 'Re': 1764, 'ut': 11379, 'er': 38103, 's</w>': 13077, 'Piy': 2085, 'asa</w>': 2160, 'izley': 1534, 'ilerinin</w>': 5110, 'genel</w>': 6201, 'beklent': 2333, 'isi</w>': 24899, 'ise</w>': 46137, '8': 17710, '’in</w>': 14637, 'altında</w>': 7492, 'bir</w>': 296811, 'acağ': 6376, 'ı.</w>': 6037, 'Reklam</w>': 1491, 'B': 58459, 'lo': 3631, 'om': 11544, 'ber': 7841, 'g</w>': 4687, 'In': 1720, 'tern': 445, 'at': 60204, 'i': 38162, 'al': 70300, '’da</w>': 10829, 'yer</w>': 39600, 'alan</w>': 19560, 'habere</w>': 1532, 'göre</w>': 26287, 'es</w>': 9633, 'cuma</w>': 1305, 'günü</w>': 9925, 'yayın': 3639, 'ladığı</w>': 4856, 'rapor': 4714, 'da</w>': 173223, 'piyasa</w>': 934, 'ak': 38402, 'sine</w>': 2067, 'yeni</w>': 25785, 'kriz</w>': 1086, 'acağını</w>': 8711, 'ön': 12159, 'gördü.</w>': 1509, 'Ban': 2004, 'kanın</w>': 1049, 'geliş': 7171, 'mekte</w>': 1323, 'olan</w>': 50569, 'pazar': 5062, 'lar</w>': 62506, 'str': 1559, 'e': 38559, 'ji</w>': 1391, 'dir': 8228, 'ektörü</w>': 1311, 'C': 47982, 'r': 50488, 'isti': 635, 'an</w>': 75847, 'M': 60727, 'ag': 8159, 'gi': 1637, 'o,</w>': 5652, 'daha</w>': 54707, 'önce</w>': 19949, 'ilk</w>': 32035, 'ada</w>': 17126, 'böyle</w>': 7791, 'olacağını</w>': 2465, 'müş': 3260, ',</w>': 174612, 'fakat</w>': 1412, '‘': 19890, 'koşul': 2074, 'kendisini</w>': 3084, 'bunun</w>': 5979, 'ikinci</w>': 8060, 'çeyr': 822, 'ekten</w>': 2041, 'olmay': 3810, 'ın': 23533, 'a': 33985, '’</w>': 15925, 'karar</w>': 8577, 'ver': 46319, 'miş.</w>': 2092, 'Merkez</w>': 3180, 'Bank': 3289, '’nın</w>': 4924, 'Haziran</w>': 2447, 've</w>': 513163, 'Temmuz': 1055, 'faiz': 1213, 'leri</w>': 52709, '400</w>': 1806, 'b': 51513, 'az</w>': 16856, 'puan</w>': 5573, 'artır': 6695, 'mak</w>': 27892, 'zorunda</w>': 2267, 'kal': 32401, 'gören</w>': 4024, 'o</w>': 39922, 'şu</w>': 11299, 'değerlendir': 7998, 'meyi</w>': 4871, 'yaptı': 3038, '“': 55633, 'Türk</w>': 18068, 'asında</w>': 11133, 'tip': 766, 'ik</w>': 21879, 'ş': 26963, 'ab': 17474, 'l': 53663, 'on</w>': 14630, 'kriz': 1255, 'den</w>': 24267, 'diğer': 893, 'ine</w>': 35642, 'geç': 20255, 'mesi,</w>': 2557, 'arada</w>': 2381, 'n': 42005, 'isp': 294, 'et': 31213, 'en</w>': 110149, 'sak': 4987, 'in</w>': 56545, 'dönem</w>': 3567, 'yaşan': 5447, 'mas': 14043, 'ıdır.</w>': 3046, 'Biz</w>': 11449, 'anda</w>': 10271, 'bu</w>': 116213, 'dönem': 5831, 'lerden</w>': 9907, 'bir': 14032, 'inde</w>': 29451, 'olduğ': 4427, 'umuzu</w>': 1415, 'düşünüyor': 1567, 'uz': 15522, '.”</w>': 7057, 'Rek': 981, 'lam': 12321, '""': 16520, 'P': 44355, 'İ': 21977, 'AR</w>': 3979, 'Araştır': 1095, 'ma': 5065, 'Adana</w>': 2543, 'Antal': 3717, 'ya’da</w>': 2125, 'millet</w>': 2101, 'ittifak': 3341, 'ı': 25526, 'avantaj': 1838, 'lı</w>': 32118, 'konum': 2743, ':21</w>': 1283, 'Akdeniz</w>': 1187, 'bölgesinde</w>': 1868, 'yürüt': 2497, 'tüğü</w>': 1796, 'anket': 1061, 'e</w>': 78149, 'Kahramanmar': 1003, 'aş': 17684, '’ta</w>': 3640, '</w>': 82596, 'cumhur': 1695, 'ittifakı</w>': 1131, 'Is': 1821, 'part': 8886, 'a’da</w>': 3193, 'MHP</w>': 3312, 'önde</w>': 1939, 'görün': 4524, 'ür': 14632, 'ken,</w>': 10126, 'Hat': 3384, 'ay,</w>': 4123, 'üyor.</w>': 3528, 'Araştırma</w>': 2236, '26</w>': 4204, 'Şu ...
# Number of tokens: 9945
# ==========
# Iter: 0
# Best pair: ('ver', 'di:</w>')
# Tokens lenght: 9946
# ==========
# Iter: 1
# Best pair: ('has', 'sas')
# Tokens lenght: 9947
# ==========
# Iter: 2
# Best pair: ('g', 'rubu</w>')
# Tokens lenght: 9948
# ==========
# Iter: 3
# Best pair: ('ak', 'tiv')
# Tokens lenght: 9949
# ==========
# Iter: 4
# Best pair: ('r', 'ı</w>')
# Tokens lenght: 9950
# ==========
# Iter: 5
# Best pair: ('ımız', 'la</w>')
# Tokens lenght: 9951
# ==========
# Iter: 6
# Best pair: ('genel', 'likle</w>')
# Tokens lenght: 9952
# ==========
# Iter: 7
# Best pair: ('(', 'S')
# Tokens lenght: 9953
# ==========
# Iter: 8
# Best pair: ('Y', 'ER')
# Tokens lenght: 9954
# ==========
# Iter: 9
# Best pair: ('PKK', "'nın</w>")
# Tokens lenght: 9955
# ==========
# Iter: 10
# Best pair: ('m', 'eden')
# Tokens lenght: 9956
# ==========
# Iter: 11
# Best pair: ('ıl', 'dı</w>')
# Tokens lenght: 9957
# ==========
# Iter: 12
# Best pair: ('cu', ',</w>')
# Tokens lenght: 9958
# ==========
# Iter: 13
# Best pair: ('memur', 'u</w>')
# Tokens lenght: 9959
# ==========
# Iter: 14
# Best pair: ('lik', 'ten</w>')
# Tokens lenght: 9960
# ==========
# Iter: 15
# Best pair: ('itir', 'af</w>')
# Tokens lenght: 9961
# ==========
# Iter: 16
# Best pair: ('Dan', 'ış')
# Tokens lenght: 9962
# ==========
# Iter: 17
# Best pair: ('nit', 'eliğ')
# Tokens lenght: 9963
# ==========
# Iter: 18
# Best pair: ('kent', 'te</w>')
# Tokens lenght: 9964
# ==========
# Iter: 19
# Best pair: ('Çak', 'ır')
# Tokens lenght: 9965
# ==========
# Iter: 20
# Best pair: ('j', 'ant')
# Tokens lenght: 9966
# ==========
# Iter: 21
# Best pair: ('en', 'te')
# Tokens lenght: 9967
# ==========
# Iter: 22
# Best pair: ('geldiğ', 'inde</w>')
# Tokens lenght: 9968
# ==========
# Iter: 23
# Best pair: ('ek', 'lerini</w>')
# Tokens lenght: 9969
# ==========
# Iter: 24
# Best pair: ('İ', 'P</w>')
# Tokens lenght: 9970
# ==========
# Iter: 25
# Best pair: ('ı', 'larla</w>')
# Tokens lenght: 9971
# ==========
# Iter: 26
# Best pair: ('kap', 'ı</w>')
# Tokens lenght: 9972
# ==========
# Iter: 27
# Best pair: ('en', 'n')
# Tokens lenght: 9973
# ==========
# Iter: 28
# Best pair: ('H', 'AL')
# Tokens lenght: 9974
# ==========
# Iter: 29
# Best pair: ('üret', 'ilen</w>')
# Tokens lenght: 9975
# ==========
# Iter: 30
# Best pair: ('benz', 'eri</w>')
# Tokens lenght: 9976
# ==========
# Iter: 31
# Best pair: ('C', 'ey')
# Tokens lenght: 9977
# ==========
# Iter: 32
# Best pair: ('z', 'at')
# Tokens lenght: 9978
# ==========
# Iter: 33
# Best pair: ('Dis', 'iplin</w>')
# Tokens lenght: 9979
# ==========
# Iter: 34
# Best pair: ('Kayseris', 'por')
# Tokens lenght: 9980
# ==========
# Iter: 35
# Best pair: ('Mobil', 'ya</w>')
# Tokens lenght: 9981
# ==========
# Iter: 36
# Best pair: ('b', 'e,</w>')
# Tokens lenght: 9982
# ==========
# Iter: 37
# Best pair: ('v', 'a')
# Tokens lenght: 9983
# ==========
# Iter: 38
# Best pair: ('U', 'C')
# Tokens lenght: 9984
# ==========
# Iter: 39
# Best pair: ('yüz', 'üne</w>')
# Tokens lenght: 9985
# ==========
# Iter: 40
# Best pair: ('mü', 't')
# Tokens lenght: 9986
# ==========
# Iter: 41
# Best pair: ('İş', 'letm')
# Tokens lenght: 9987
# ==========
# Iter: 42
# Best pair: ('teklif', 'i</w>')
# Tokens lenght: 9988
# ==========
# Iter: 43
# Best pair: ('üzer', 'ine,</w>')
# Tokens lenght: 9989
# ==========
# Iter: 44
# Best pair: ('ş', 'iş')
# Tokens lenght: 9990
# ==========
# Iter: 45
# Best pair: ('YOR', 'UM')
# Tokens lenght: 9991
# ==========
# Iter: 46
# Best pair: ('ham', 'l')
# Tokens lenght: 9992
# ==========
# Iter: 47
# Best pair: ('l', 'ü,</w>')
# Tokens lenght: 9993
# ==========
# Iter: 48
# Best pair: ('ul', 'u</w>')
# Tokens lenght: 9994
# ==========
# Iter: 49
# Best pair: ('Oper', 'asyon')
# Tokens lenght: 9995
# ==========
# Iter: 50
# Best pair: ('bey', 'in</w>')
# Tokens lenght: 9996
# ==========
# Iter: 51
# Best pair: ('BAŞ', 'VUR')
# Tokens lenght: 9997
# ==========
# Iter: 52
# Best pair: ('ak', 'tüel</w>')
# Tokens lenght: 9998
# ==========
# Iter: 53
# Best pair: ('olacak', '?</w>')
# Tokens lenght: 9999
# ==========
# Iter: 54
# Best pair: ('gel', 'miş</w>')
# Tokens lenght: 10000
# ==========
# Iter: 55
# Best pair: ('tık', 'tan</w>')
# Tokens lenght: 10001
# ==========
# Iter: 56
# Best pair: ('ah', 'it</w>')
# Tokens lenght: 10002
# ==========
# Iter: 57
# Best pair: ('il', 'lerde</w>')
# Tokens lenght: 10003
# ==========
# Iter: 58
# Best pair: ('ver', 'ecek.</w>')
# Tokens lenght: 10004
# ==========
# Iter: 59
# Best pair: ('u', 'larak</w>')
# Tokens lenght: 10005
# ==========
# Iter: 60
# Best pair: ('protes', 'to</w>')
# Tokens lenght: 10006
# ==========
# Iter: 61
# Best pair: ('uyor', ',</w>')
# Tokens lenght: 10007
# ==========
# Iter: 62
# Best pair: ('sağ', 'lıyor.</w>')
# Tokens lenght: 10008
# ==========
# Iter: 63
# Best pair: ('O', 't')
# Tokens lenght: 10009
# ==========
# Iter: 64
# Best pair: ('uştur', 'ma</w>')
# Tokens lenght: 10010
# ==========
# Iter: 65
# Best pair: ('Kör', 'f')
# Tokens lenght: 10011
# ==========
# Iter: 66
# Best pair: ('ust', 'a</w>')
# Tokens lenght: 10012
# ==========
# Iter: 67
# Best pair: ('ism', 'ini</w>')
# Tokens lenght: 10013
# ==========
# Iter: 68
# Best pair: ('lulu', 'k</w>')
# Tokens lenght: 10014
# ==========
# Iter: 69
# Best pair: ('geliş', 'en</w>')
# Tokens lenght: 10015
# ==========
# Iter: 70
# Best pair: ('gel', 'iyor</w>')
# Tokens lenght: 10016
# ==========
# Iter: 71
# Best pair: ('Ş', 'ır')
# Tokens lenght: 10017
# ==========
# Iter: 72
# Best pair: ('Bir', 'inci</w>')
# Tokens lenght: 10018
# ==========
# Iter: 73
# Best pair: ('Net', 'an')
# Tokens lenght: 10019
# ==========
# Iter: 74
# Best pair: ('Val', 'iliğ')
# Tokens lenght: 10020
# ==========
# Iter: 75
# Best pair: ('at', 'ış')
# Tokens lenght: 10021
# ==========
# Iter: 76
# Best pair: ('ken', 'di')
# Tokens lenght: 10022
# ==========
# Iter: 77
# Best pair: ('e', 'uro</w>')
# Tokens lenght: 10023
# ==========
# Iter: 78
# Best pair: ('Gü', 'ç')
# Tokens lenght: 10024
# ==========
# Iter: 79
# Best pair: ('mücade', 'leyi</w>')
# Tokens lenght: 10025
# ==========
# Iter: 80
# Best pair: ('hayat', 'ına</w>')
# Tokens lenght: 10026
# ==========
# Iter: 81
# Best pair: ('D', 'ay')
# Tokens lenght: 10027
# ==========
# Iter: 82
# Best pair: ('v', 'er</w>')
# Tokens lenght: 10028
# ==========
# Iter: 83
# Best pair: ('ıyor', 'sun')
# Tokens lenght: 10029
# ==========
# Iter: 84
# Best pair: ('plan', 'ı</w>')
# Tokens lenght: 10030
# ==========
# Iter: 85
# Best pair: ('bırak', 'tı.</w>')
# Tokens lenght: 10031
# ==========
# Iter: 86
# Best pair: ('b', 'inden</w>')
# Tokens lenght: 10032
# ==========
# Iter: 87
# Best pair: ('M', 'H')
# Tokens lenght: 10033
# ==========
# Iter: 88
# Best pair: ('Siv', 'as</w>')
# Tokens lenght: 10034
# ==========
# Iter: 89
# Best pair: ('M', 'in')
# Tokens lenght: 10035
# ==========
# Iter: 90
# Best pair: ('ver', 'miş</w>')
# Tokens lenght: 10036
# ==========
# Iter: 91
# Best pair: ('Turk', 'cel')
# Tokens lenght: 10037
# ==========
# Iter: 92
# Best pair: ('Netan', 'yah')
# Tokens lenght: 10038
# ==========
# Iter: 93
# Best pair: ('bab', 'asının</w>')
# Tokens lenght: 10039
# ==========
# Iter: 94
# Best pair: ('n', 'ih')
# Tokens lenght: 10040
# ==========
# Iter: 95
# Best pair: ('kim', 'liği</w>')
# Tokens lenght: 10041
# ==========
# Iter: 96
# Best pair: ('K', 'aya</w>')
# Tokens lenght: 10042
# ==========
# Iter: 97
# Best pair: ('öğrenc', 'ileri</w>')
# Tokens lenght: 10043
# ==========
# Iter: 98
# Best pair: ('insan', 'lara</w>')
# Tokens lenght: 10044
# ==========
# Iter: 99
# Best pair: ('kıs', 'ıt')
# Tokens lenght: 10045
# ==========
# Iter: 100
# Best pair: ('ör', 't')
# Tokens lenght: 10046
# ==========
# Iter: 101
# Best pair: ('ün', 'ü,</w>')
# Tokens lenght: 10047
# ==========
# Iter: 102
# Best pair: ('an', 'üstü</w>')
# Tokens lenght: 10048
# ==========
# Iter: 103
# Best pair: ('6', '3</w>')
# Tokens lenght: 10049
# ==========
# Iter: 104
# Best pair: ('ların', 'a,</w>')
# Tokens lenght: 10050
# ==========
# Iter: 105
# Best pair: ('c', 'lass')
# Tokens lenght: 10051
# ==========
# Iter: 106
# Best pair: ('il', 'ler</w>')
# Tokens lenght: 10052
# ==========
# Iter: 107
# Best pair: ('Ad', 'nan</w>')
# Tokens lenght: 10053
# ==========
# Iter: 108
# Best pair: ('ey', 'lem</w>')
# Tokens lenght: 10054
# ==========
# Iter: 109
# Best pair: ('pro', 'gram</w>')
# Tokens lenght: 10055
# ==========
# Iter: 110
# Best pair: ('başar', 'dı.</w>')
# Tokens lenght: 10056
# ==========
# Iter: 111
# Best pair: ('mus', 'unuz')
# Tokens lenght: 10057
# ==========
# Iter: 112
# Best pair: ('d', 'ro')
# Tokens lenght: 10058
# ==========
# Iter: 113
# Best pair: ('diz', 'isi</w>')
# Tokens lenght: 10059
# ==========
# Iter: 114
# Best pair: ('an', 'ti')
# Tokens lenght: 10060
# ==========
# Iter: 115
# Best pair: ('Rus', "ya'nın</w>")
# Tokens lenght: 10061
# ==========
# Iter: 116
# Best pair: ('O', 'F')
# Tokens lenght: 10062
# ==========
# Iter: 117
# Best pair: ('(xx', '),</w>')
# Tokens lenght: 10063
# ==========
# Iter: 118
# Best pair: ('J', 'on')
# Tokens lenght: 10064
# ==========
# Iter: 119
# Best pair: ('Futb', 'ol')
# Tokens lenght: 10065
# ==========
# Iter: 120
# Best pair: ('gar', 'ant')
# Tokens lenght: 10066
# ==========
# Iter: 121
# Best pair: ('düzenlen', 'ecek</w>')
# Tokens lenght: 10067
# ==========
# Iter: 122
# Best pair: ('uz', 'un')
# Tokens lenght: 10068
# ==========
# Iter: 123
# Best pair: ('le', 'dik.</w>')
# Tokens lenght: 10069
# ==========
# Iter: 124
# Best pair: ('tan', 'esi</w>')
# Tokens lenght: 10070
# ==========
# Iter: 125
# Best pair: ('Güm', 'r')
# Tokens lenght: 10071
# ==========
# Iter: 126
# Best pair: ('CHP', ',</w>')
# Tokens lenght: 10072
# ==========
# Iter: 127
# Best pair: ('paylaş', 'tığı</w>')
# Tokens lenght: 10073
# ==========
# Iter: 128
# Best pair: ('büt', 'çe</w>')
# Tokens lenght: 10074
# ==========
# Iter: 129
# Best pair: ('kas', 'ten</w>')
# Tokens lenght: 10075
# ==========
# Iter: 130
# Best pair: ('Yav', 'uz</w>')
# Tokens lenght: 10076
# ==========
# Iter: 131
# Best pair: ('AND', 'I</w>')
# Tokens lenght: 10077
# ==========
# Iter: 132
# Best pair: ('yol', 'una</w>')
# Tokens lenght: 10078
# ==========
# Iter: 133
# Best pair: ('u’n', 'a</w>')
# Tokens lenght: 10079
# ==========
# Iter: 134
# Best pair: ('ma', 'aş</w>')
# Tokens lenght: 10080
# ==========
# Iter: 135
# Best pair: ('sorus', 'una</w>')
# Tokens lenght: 10081
# ==========
# Iter: 136
# Best pair: ('mekt', 'edir')
# Tokens lenght: 10082
# ==========
# Iter: 137
# Best pair: ('ın', 'ızı</w>')
# Tokens lenght: 10083
# ==========
# Iter: 138
# Best pair: ('çıkar', 'ıldı.</w>')
# Tokens lenght: 10084
# ==========
# Iter: 139
# Best pair: ('ı', 'tım</w>')
# Tokens lenght: 10085
# ==========
# Iter: 140
# Best pair: ('m', 'uy')
# Tokens lenght: 10086
# ==========
# Iter: 141
# Best pair: ('kuy', 'ruk')
# Tokens lenght: 10087
# ==========
# Iter: 142
# Best pair: ('Burhan', 'ettin</w>')
# Tokens lenght: 10088
# ==========
# Iter: 143
# Best pair: ('T', 'asar')
# Tokens lenght: 10089
# ==========
# Iter: 144
# Best pair: ('OL', 'DU')
# Tokens lenght: 10090
# ==========
# Iter: 145
# Best pair: ('et', 'ki</w>')
# Tokens lenght: 10091
# ==========
# Iter: 146
# Best pair: ('başar', 'ıyla</w>')
# Tokens lenght: 10092
# ==========
# Iter: 147
# Best pair: ('den', 'il')
# Tokens lenght: 10093
# ==========
# Iter: 148
# Best pair: ('uz', '”</w>')
# Tokens lenght: 10094
# ==========
# Iter: 149
# Best pair: ('belir', 'li</w>')
# Tokens lenght: 10095
# ==========
# Iter: 150
# Best pair: ('müt', 'tef')
# Tokens lenght: 10096
# ==========
# Iter: 151
# Best pair: ('Ar', 'jant')
# Tokens lenght: 10097
# ==========
# Iter: 152
# Best pair: ('Rab', 'b')
# Tokens lenght: 10098
# ==========
# Iter: 153
# Best pair: ('Çarşam', 'ba,</w>')
# Tokens lenght: 10099
# ==========
# Iter: 154
# Best pair: ('Mu', 'har')
# Tokens lenght: 10100
# ==========
# Iter: 155
# Best pair: ('ez', ',</w>')
# Tokens lenght: 10101
# ==========
# Iter: 156
# Best pair: ('gördük', '.</w>')
# Tokens lenght: 10102
# ==========
# Iter: 157
# Best pair: ('an', 'lar')
# Tokens lenght: 10103
# ==========
# Iter: 158
# Best pair: ('başvuru', 'ları</w>')
# Tokens lenght: 10104
# ==========
# Iter: 159
# Best pair: ('yorum', ',</w>')
# Tokens lenght: 10105
# ==========
# Iter: 160
# Best pair: ('Ş', 'EH')
# Tokens lenght: 10106
# ==========
# Iter: 161
# Best pair: ('ede', 'k')
# Tokens lenght: 10107
# ==========
# Iter: 162
# Best pair: ('er', 'ken,</w>')
# Tokens lenght: 10108
# ==========
# Iter: 163
# Best pair: ('kar', 'tı</w>')
# Tokens lenght: 10109
# ==========
# Iter: 164
# Best pair: ('L', 'a')
# Tokens lenght: 10110
# ==========
# Iter: 165
# Best pair: ('gör', 'ü')
# Tokens lenght: 10111
# ==========
# Iter: 166
# Best pair: ('Em', 'ine</w>')
# Tokens lenght: 10112
# ==========
# Iter: 167
# Best pair: ('hav', 'aliman')
# Tokens lenght: 10113
# ==========
# Iter: 168
# Best pair: ('el', 'im.</w>')
# Tokens lenght: 10114
# ==========
# Iter: 169
# Best pair: ('tur', 'iz')
# Tokens lenght: 10115
# ==========
# Iter: 170
# Best pair: ('di', '\\"</w>')
# Tokens lenght: 10116
# ==========
# Iter: 171
# Best pair: ('N', '.')
# Tokens lenght: 10117
# ==========
# Iter: 172
# Best pair: ('temiz', 'lik</w>')
# Tokens lenght: 10118
# ==========
# Iter: 173
# Best pair: ('kadro', 's')
# Tokens lenght: 10119
# ==========
# Iter: 174
# Best pair: ('başkan', 'lık</w>')
# Tokens lenght: 10120
# ==========
# Iter: 175
# Best pair: ('Ru', 'han')
# Tokens lenght: 10121
# ==========
# Iter: 176
# Best pair: ('H', 'ır')
# Tokens lenght: 10122
# ==========
# Iter: 177
# Best pair: ('Kor', 'uma</w>')
# Tokens lenght: 10123
# ==========
# Iter: 178
# Best pair: ('proj', 'elerini</w>')
# Tokens lenght: 10124
# ==========
# Iter: 179
# Best pair: ('kuvvet', 'li</w>')
# Tokens lenght: 10125
# ==========
# Iter: 180
# Best pair: ('DÜ', 'Ş')
# Tokens lenght: 10126
# ==========
# Iter: 181
# Best pair: ('isim', 'lerin</w>')
# Tokens lenght: 10127
# ==========
# Iter: 182
# Best pair: ('hayat', 'ın</w>')
# Tokens lenght: 10128
# ==========
# Iter: 183
# Best pair: ('Ar', 'kadaş')
# Tokens lenght: 10129
# ==========
# Iter: 184
# Best pair: ('bur', 'adaki</w>')
# Tokens lenght: 10130
# ==========
# Iter: 185
# Best pair: ('ekip', 'ler,</w>')
# Tokens lenght: 10131
# ==========
# Iter: 186
# Best pair: ('der', 'e</w>')
# Tokens lenght: 10132
# ==========
# Iter: 187
# Best pair: ('L', 'U</w>')
# Tokens lenght: 10133
# ==========
# Iter: 188
# Best pair: ('sez', 'onun</w>')
# Tokens lenght: 10134
# ==========
# Iter: 189
# Best pair: ('16', '.02.2019</w>')
# Tokens lenght: 10135
# ==========
# Iter: 190
# Best pair: ('göz', 'et')
# Tokens lenght: 10136
# ==========
# Iter: 191
# Best pair: ('TÜ', '</w>')
# Tokens lenght: 10137
# ==========
# Iter: 192
# Best pair: ('ebilir', 'siniz.</w>')
# Tokens lenght: 10138
# ==========
# Iter: 193
# Best pair: ('genç', 'ler</w>')
# Tokens lenght: 10139
# ==========
# Iter: 194
# Best pair: ('uz', 'u</w>')
# Tokens lenght: 10140
# ==========
# Iter: 195
# Best pair: ('N', 'eden</w>')
# Tokens lenght: 10141
# ==========
# Iter: 196
# Best pair: ('Zir', 'v')
# Tokens lenght: 10142
# ==========
# Iter: 197
# Best pair: ('Çelik', ',</w>')
# Tokens lenght: 10143
# ==========
# Iter: 198
# Best pair: ('vurg', 'u</w>')
# Tokens lenght: 10144
# ==========
# Iter: 199
# Best pair: ('sür', 'eli</w>')
# Tokens lenght: 10145
# ==========
# Iter: 200
# Best pair: ('ey', 'gam')
# Tokens lenght: 10146
# ==========
# Iter: 201
# Best pair: ('10', '.03.2019</w>')
# Tokens lenght: 10147
# ==========
# Iter: 202
# Best pair: ('teş', 'eb')
# Tokens lenght: 10148
# ==========
# Iter: 203
# Best pair: ('olur', 'ken,</w>')
# Tokens lenght: 10149
# ==========
# Iter: 204
# Best pair: ('ifade', 'si</w>')
# Tokens lenght: 10150
# ==========
# Iter: 205
# Best pair: ('d', 'ük</w>')
# Tokens lenght: 10151
# ==========
# Iter: 206
# Best pair: ('r', 'ic')
# Tokens lenght: 10152
# ==========
# Iter: 207
# Best pair: ('Tem', 'el</w>')
# Tokens lenght: 10153
# ==========
# Iter: 208
# Best pair: ('desteğ', 'iyle</w>')
# Tokens lenght: 10154
# ==========
# Iter: 209
# Best pair: ('zinc', 'ir')
# Tokens lenght: 10155
# ==========
# Iter: 210
# Best pair: ('mu', 'haf')
# Tokens lenght: 10156
# ==========
# Iter: 211
# Best pair: ('Gaz', 'i</w>')
# Tokens lenght: 10157
# ==========
# Iter: 212
# Best pair: ('tüğ', 'ünü</w>')
# Tokens lenght: 10158
# ==========
# Iter: 213
# Best pair: ('C', 'or')
# Tokens lenght: 10159
# ==========
# Iter: 214
# Best pair: ('ı', '’</w>')
# Tokens lenght: 10160
# ==========
# Iter: 215
# Best pair: ('Gör', 'ün')
# Tokens lenght: 10161
# ==========
# Iter: 216
# Best pair: ('FETÖ', '/PD')
# Tokens lenght: 10162
# ==========
# Iter: 217
# Best pair: ('k', 'abil')
# Tokens lenght: 10163
# ==========
# Iter: 218
# Best pair: ('ac', 'ık</w>')
# Tokens lenght: 10164
# ==========
# Iter: 219
# Best pair: ('sorun', 'larını</w>')
# Tokens lenght: 10165
# ==========
# Iter: 220
# Best pair: ('ılık', ',</w>')
# Tokens lenght: 10166
# ==========
# Iter: 221
# Best pair: ('kal', 'may')
# Tokens lenght: 10167
# ==========
# Iter: 222
# Best pair: ('dav', 'ada</w>')
# Tokens lenght: 10168
# ==========
# Iter: 223
# Best pair: ('ağ', '</w>')
# Tokens lenght: 10169
# ==========
# Iter: 224
# Best pair: ('fin', 'ale</w>')
# Tokens lenght: 10170
# ==========
# Iter: 225
# Best pair: ('ladık', 'larını</w>')
# Tokens lenght: 10171
# ==========
# Iter: 226
# Best pair: ('hazır', 'ladığı</w>')
# Tokens lenght: 10172
# ==========
# Iter: 227
# Best pair: ('giy', 'en</w>')
# Tokens lenght: 10173
# ==========
# Iter: 228
# Best pair: ('i', 'on')
# Tokens lenght: 10174
# ==========
# Iter: 229
# Best pair: ('Bakan', 'lık</w>')
# Tokens lenght: 10175
# ==========
# Iter: 230
# Best pair: ('tı', '.')
# Tokens lenght: 10176
# ==========
# Iter: 231
# Best pair: ('zor', 'luk')
# Tokens lenght: 10177
# ==========
# Iter: 232
# Best pair: ('al', 'dır')
# Tokens lenght: 10178
# ==========
# Iter: 233
# Best pair: ('plan', 'lanan</w>')
# Tokens lenght: 10179
# ==========
# Iter: 234
# Best pair: ('Bur', 'adan</w>')
# Tokens lenght: 10180
# ==========
# Iter: 235
# Best pair: ('yap', 'ım')
# Tokens lenght: 10181
# ==========
# Iter: 236
# Best pair: ('Kas', 'tam')
# Tokens lenght: 10182
# ==========
# Iter: 237
# Best pair: ('doğ', 'u</w>')
# Tokens lenght: 10183
# ==========
# Iter: 238
# Best pair: ('karş', 'ın</w>')
# Tokens lenght: 10184
# ==========
# Iter: 239
# Best pair: ('p', 'ek')
# Tokens lenght: 10185
# ==========
# Iter: 240
# Best pair: ('Er', 'kan</w>')
# Tokens lenght: 10186
# ==========
# Iter: 241
# Best pair: ('C', 'O')
# Tokens lenght: 10187
# ==========
# Iter: 242
# Best pair: ('acak', 'lar.</w>')
# Tokens lenght: 10188
# ==========
# Iter: 243
# Best pair: ('alar', 'ca</w>')
# Tokens lenght: 10189
# ==========
# Iter: 244
# Best pair: ('s', 'om')
# Tokens lenght: 10190
# ==========
# Iter: 245
# Best pair: ('eş', 'inin</w>')
# Tokens lenght: 10191
# ==========
# Iter: 246
# Best pair: ('ılı', 'ğını</w>')
# Tokens lenght: 10192
# ==========
# Iter: 247
# Best pair: ('Madr', 'id</w>')
# Tokens lenght: 10193
# ==========
# Iter: 248
# Best pair: ('iç', 'in.</w>')
# Tokens lenght: 10194
# ==========
# Iter: 249
# Best pair: ('el', 'iği</w>')
# Tokens lenght: 10195
# ==========
# Iter: 250
# Best pair: ('rak', 'ibi</w>')
# Tokens lenght: 10196
# ==========
# Iter: 251
# Best pair: ('değerlendirmeler', 'de</w>')
# Tokens lenght: 10197
# ==========
# Iter: 252
# Best pair: ('eğ', 'inde</w>')
# Tokens lenght: 10198
# ==========
# Iter: 253
# Best pair: ('ay', 'arak</w>')
# Tokens lenght: 10199
# ==========
# Iter: 254
# Best pair: ('fırt', 'ına</w>')
# Tokens lenght: 10200
# ==========
# Iter: 255
# Best pair: ('Is', 'part')
# Tokens lenght: 10201
# ==========
# Iter: 256
# Best pair: ('sürüc', 'üs')
# Tokens lenght: 10202
# ==========
# Iter: 257
# Best pair: ('düzen', 'li</w>')
# Tokens lenght: 10203
# ==========
# Iter: 258
# Best pair: ('1-', '1</w>')
# Tokens lenght: 10204
# ==========
# Iter: 259
# Best pair: ('Insta', 'gram</w>')
# Tokens lenght: 10205
# ==========
# Iter: 260
# Best pair: ('ebil', 'eceği</w>')
# Tokens lenght: 10206
# ==========
# Iter: 261
# Best pair: ('uç', 'uş</w>')
# Tokens lenght: 10207
# ==========
# Iter: 262
# Best pair: ('Bodr', 'um')
# Tokens lenght: 10208
# ==========
# Iter: 263
# Best pair: ('L', '</w>')
# Tokens lenght: 10209
# ==========
# Iter: 264
# Best pair: ('ıntı', 'lar</w>')
# Tokens lenght: 10210
# ==========
# Iter: 265
# Best pair: ('ol', 'say')
# Tokens lenght: 10211
# ==========
# Iter: 266
# Best pair: ('Malat', 'yaspor')
# Tokens lenght: 10212
# ==========
# Iter: 267
# Best pair: ('Ş', 'ük')
# Tokens lenght: 10213
# ==========
# Iter: 268
# Best pair: ('kon', 'uya</w>')
# Tokens lenght: 10214
# ==========
# Iter: 269
# Best pair: ('adı', 'yla</w>')
# Tokens lenght: 10215
# ==========
# Iter: 270
# Best pair: ('çık', 'acak</w>')
# Tokens lenght: 10216
# ==========
# Iter: 271
# Best pair: ('bilim', 'sel</w>')
# Tokens lenght: 10217
# ==========
# Iter: 272
# Best pair: ('Kon', 'tr')
# Tokens lenght: 10218
# ==========
# Iter: 273
# Best pair: ('Güneş', ',</w>')
# Tokens lenght: 10219
# ==========
# Iter: 274
# Best pair: ('derb', 'i</w>')
# Tokens lenght: 10220
# ==========
# Iter: 275
# Best pair: ('kent', 'in</w>')
# Tokens lenght: 10221
# ==========
# Iter: 276
# Best pair: ('rapor', 'u</w>')
# Tokens lenght: 10222
# ==========
# Iter: 277
# Best pair: ('helikop', 'ter</w>')
# Tokens lenght: 10223
# ==========
# Iter: 278
# Best pair: ('ilişk', 'ileri</w>')
# Tokens lenght: 10224
# ==========
# Iter: 279
# Best pair: ('S', 'AĞ')
# Tokens lenght: 10225
# ==========
# Iter: 280
# Best pair: ('0', '3</w>')
# Tokens lenght: 10226
# ==========
# Iter: 281
# Best pair: ('ay', 'olu</w>')
# Tokens lenght: 10227
# ==========
# Iter: 282
# Best pair: ('Rega', 'ip</w>')
# Tokens lenght: 10228
# ==========
# Iter: 283
# Best pair: ('at', 'an')
# Tokens lenght: 10229
# ==========
# Iter: 284
# Best pair: ('im', 'kâ')
# Tokens lenght: 10230
# ==========
# Iter: 285
# Best pair: ('gen', 'c')
# Tokens lenght: 10231
# ==========
# Iter: 286
# Best pair: ('lan', 'mış</w>')
# Tokens lenght: 10232
# ==========
# Iter: 287
# Best pair: ('ad', 'al')
# Tokens lenght: 10233
# ==========
# Iter: 288
# Best pair: ('Şubat', '’ta</w>')
# Tokens lenght: 10234
# ==========
# Iter: 289
# Best pair: ('pil', 'ot')
# Tokens lenght: 10235
# ==========
# Iter: 290
# Best pair: ('emiz', 'in</w>')
# Tokens lenght: 10236
# ==========
# Iter: 291
# Best pair: ('U', 'mut</w>')
# Tokens lenght: 10237
# ==========
# Iter: 292
# Best pair: ('E', 'z')
# Tokens lenght: 10238
# ==========
# Iter: 293
# Best pair: ('mutlulu', 'k</w>')
# Tokens lenght: 10239
# ==========
# Iter: 294
# Best pair: ('iyorsun', 'uz.</w>')
# Tokens lenght: 10240
# ==========
# Iter: 295
# Best pair: ('Tur', 'han,</w>')
# Tokens lenght: 10241
# ==========
# Iter: 296
# Best pair: ('Er', 'en</w>')
# Tokens lenght: 10242
# ==========
# Iter: 297
# Best pair: ('Zeyn', 'ep</w>')
# Tokens lenght: 10243
# ==========
# Iter: 298
# Best pair: ('sezon', 'unda</w>')
# Tokens lenght: 10244
# ==========
# Iter: 299
# Best pair: ('5', '6</w>')
# Tokens lenght: 10245
# ==========
# Iter: 300
# Best pair: ('geril', 'edi.</w>')
# Tokens lenght: 10246
# ==========
# Iter: 301
# Best pair: ('R', 'uh')
# Tokens lenght: 10247
# ==========
# Iter: 302
# Best pair: ('g', '-')
# Tokens lenght: 10248
# ==========
# Iter: 303
# Best pair: ('inan', 'ıyorum.</w>')
# Tokens lenght: 10249
# ==========
# Iter: 304
# Best pair: ('mahkem', 'ece</w>')
# Tokens lenght: 10250
# ==========
# Iter: 305
# Best pair: ('Kas', 'ap')
# Tokens lenght: 10251
# ==========
# Iter: 306
# Best pair: ('ECE', 'K</w>')
# Tokens lenght: 10252
# ==========
# Iter: 307
# Best pair: ('herk', 'esi</w>')
# Tokens lenght: 10253
# ==========
# Iter: 308
# Best pair: ('öz', '</w>')
# Tokens lenght: 10254
# ==========
# Iter: 309
# Best pair: ('olabil', 'ir</w>')
# Tokens lenght: 10255
# ==========
# Iter: 310
# Best pair: ('On', 'u</w>')
# Tokens lenght: 10256
# ==========
# Iter: 311
# Best pair: ('iti', 'f</w>')
# Tokens lenght: 10257
# ==========
# Iter: 312
# Best pair: ('A', 'P</w>')
# Tokens lenght: 10258
# ==========
# Iter: 313
# Best pair: ('dık', ',</w>')
# Tokens lenght: 10259
# ==========
# Iter: 314
# Best pair: ('göster', 'ilen</w>')
# Tokens lenght: 10260
# ==========
# Iter: 315
# Best pair: ('uyor', 'lar.</w>')
# Tokens lenght: 10261
# ==========
# Iter: 316
# Best pair: ('gün', 'düz</w>')
# Tokens lenght: 10262
# ==========
# Iter: 317
# Best pair: ('İt', 'faiye</w>')
# Tokens lenght: 10263
# ==========
# Iter: 318
# Best pair: ('D', 'ik')
# Tokens lenght: 10264
# ==========
# Iter: 319
# Best pair: ('al', 'ır')
# Tokens lenght: 10265
# ==========
# Iter: 320
# Best pair: ('üret', 'il')
# Tokens lenght: 10266
# ==========
# Iter: 321
# Best pair: ('tür', 'k</w>')
# Tokens lenght: 10267
# ==========
# Iter: 322
# Best pair: ('heyec', 'an</w>')
# Tokens lenght: 10268
# ==========
# Iter: 323
# Best pair: ('ıl', 'masını</w>')
# Tokens lenght: 10269
# ==========
# Iter: 324
# Best pair: ('Cez', 'a')
# Tokens lenght: 10270
# ==========
# Iter: 325
# Best pair: ('üst', 'ünde</w>')
# Tokens lenght: 10271
# ==========
# Iter: 326
# Best pair: ('Or', 'du</w>')
# Tokens lenght: 10272
# ==========
# Iter: 327
# Best pair: ('boş', 'alt')
# Tokens lenght: 10273
# ==========
# Iter: 328
# Best pair: ('Proj', 'e</w>')
# Tokens lenght: 10274
# ==========
# Iter: 329
# Best pair: ('teş', 'em</w>')
# Tokens lenght: 10275
# ==========
# Iter: 330
# Best pair: ('yön', 'elt')
# Tokens lenght: 10276
# ==========
# Iter: 331
# Best pair: ('Suriy', 'eli</w>')
# Tokens lenght: 10277
# ==========
# Iter: 332
# Best pair: ('Em', 'ir')
# Tokens lenght: 10278
# ==========
# Iter: 333
# Best pair: ('Yav', 'aş,</w>')
# Tokens lenght: 10279
# ==========
# Iter: 334
# Best pair: ('yok', 'tu.</w>')
# Tokens lenght: 10280
# ==========
# Iter: 335
# Best pair: ('uc', 'usu</w>')
# Tokens lenght: 10281
# ==========
# Iter: 336
# Best pair: ('H', 'en')
# Tokens lenght: 10282
# ==========
# Iter: 337
# Best pair: ('ner', 'eye</w>')
# Tokens lenght: 10283
# ==========
# Iter: 338
# Best pair: ('Z', 'aman</w>')
# Tokens lenght: 10284
# ==========
# Iter: 339
# Best pair: ('ar', 'ken,</w>')
# Tokens lenght: 10285
# ==========
# Iter: 340
# Best pair: ('taş', 'ıyor.</w>')
# Tokens lenght: 10286
# ==========
# Iter: 341
# Best pair: ('TÜRK', 'İYE')
# Tokens lenght: 10287
# ==========
# Iter: 342
# Best pair: ('al', 'ılar</w>')
# Tokens lenght: 10288
# ==========
# Iter: 343
# Best pair: ('kr', 'e')
# Tokens lenght: 10289
# ==========
# Iter: 344
# Best pair: ('tarih', 'li</w>')
# Tokens lenght: 10290
# ==========
# Iter: 345
# Best pair: ('ş', 'iir')
# Tokens lenght: 10291
# ==========
# Iter: 346
# Best pair: ('D', 'okt')
# Tokens lenght: 10292
# ==========
# Iter: 347
# Best pair: ('Y', 'urt</w>')
# Tokens lenght: 10293
# ==========
# Iter: 348
# Best pair: ('V', 'an')
# Tokens lenght: 10294
# ==========
# Iter: 349
# Best pair: ('protok', 'ol')
# Tokens lenght: 10295
# ==========
# Iter: 350
# Best pair: ('Öğr', 'etim</w>')
# Tokens lenght: 10296
# ==========
# Iter: 351
# Best pair: ('spor', 'c')
# Tokens lenght: 10297
# ==========
# Iter: 352
# Best pair: ('yaz', 'dığı</w>')
# Tokens lenght: 10298
# ==========
# Iter: 353
# Best pair: ('iç', 'inden</w>')
# Tokens lenght: 10299
# ==========
# Iter: 354
# Best pair: ('sev', 'k')
# Tokens lenght: 10300
# ==========
# Iter: 355
# Best pair: ('oyuncu', ',</w>')
# Tokens lenght: 10301
# ==========
# Iter: 356
# Best pair: ('mal', 'ıdır.</w>')
# Tokens lenght: 10302
# ==========
# Iter: 357
# Best pair: ('Ser', 'v')
# Tokens lenght: 10303
# ==========
# Iter: 358
# Best pair: ('f', 'et')
# Tokens lenght: 10304
# ==========
# Iter: 359
# Best pair: ('yargıl', 'anan</w>')
# Tokens lenght: 10305
# ==========
# Iter: 360
# Best pair: ('ah', 'h')
# Tokens lenght: 10306
# ==========
# Iter: 361
# Best pair: ('kilo', 'gram</w>')
# Tokens lenght: 10307
# ==========
# Iter: 362
# Best pair: ('ver', 'ileri</w>')
# Tokens lenght: 10308
# ==========
# Iter: 363
# Best pair: ('top', 'lanan</w>')
# Tokens lenght: 10309
# ==========
# Iter: 364
# Best pair: ('siy', 'ah-beyaz')
# Tokens lenght: 10310
# ==========
# Iter: 365
# Best pair: ('at', 'lat')
# Tokens lenght: 10311
# ==========
# Iter: 366
# Best pair: ('R', 'ey')
# Tokens lenght: 10312
# ==========
# Iter: 367
# Best pair: ('gerek', 'se</w>')
# Tokens lenght: 10313
# ==========
# Iter: 368
# Best pair: ('H', 'on')
# Tokens lenght: 10314
# ==========
# Iter: 369
# Best pair: ('sağ', 'an')
# Tokens lenght: 10315
# ==========
# Iter: 370
# Best pair: ('l', 'ezz')
# Tokens lenght: 10316
# ==========
# Iter: 371
# Best pair: ('Ön', 'cel')
# Tokens lenght: 10317
# ==========
# Iter: 372
# Best pair: ('K', 'um')
# Tokens lenght: 10318
# ==========
# Iter: 373
# Best pair: ('O', 'kan</w>')
# Tokens lenght: 10319
# ==========
# Iter: 374
# Best pair: ('görüntül', 'en')
# Tokens lenght: 10320
# ==========
# Iter: 375
# Best pair: ('s', 'osy')
# Tokens lenght: 10321
# ==========
# Iter: 376
# Best pair: ('A', 'taş')
# Tokens lenght: 10322
# ==========
# Iter: 377
# Best pair: ('ins', 'iz</w>')
# Tokens lenght: 10323
# ==========
# Iter: 378
# Best pair: ('Pol', 'is')
# Tokens lenght: 10324
# ==========
# Iter: 379
# Best pair: ('ı', 'larına</w>')
# Tokens lenght: 10325
# ==========
# Iter: 380
# Best pair: ('Stadı', "'nda</w>")
# Tokens lenght: 10326
# ==========
# Iter: 381
# Best pair: ('yav', 'aş')
# Tokens lenght: 10327
# ==========
# Iter: 382
# Best pair: ('sır', 'alam')
# Tokens lenght: 10328
# ==========
# Iter: 383
# Best pair: ('dı', '?</w>')
# Tokens lenght: 10329
# ==========
# Iter: 384
# Best pair: ('kon', 'uyu</w>')
# Tokens lenght: 10330
# ==========
# Iter: 385
# Best pair: ('Sav', 'c')
# Tokens lenght: 10331
# ==========
# Iter: 386
# Best pair: ('Yor', 'k</w>')
# Tokens lenght: 10332
# ==========
# Iter: 387
# Best pair: ('zor', 'lan')
# Tokens lenght: 10333
# ==========
# Iter: 388
# Best pair: ('yıl', 'ları</w>')
# Tokens lenght: 10334
# ==========
# Iter: 389
# Best pair: ('iyoruz', '.\\"</w>')
# Tokens lenght: 10335
# ==========
# Iter: 390
# Best pair: ('madal', 'ya</w>')
# Tokens lenght: 10336
# ==========
# Iter: 391
# Best pair: ('ü', "'nün</w>")
# Tokens lenght: 10337
# ==========
# Iter: 392
# Best pair: ('büs', '</w>')
# Tokens lenght: 10338
# ==========
# Iter: 393
# Best pair: ('6', ',</w>')
# Tokens lenght: 10339
# ==========
# Iter: 394
# Best pair: ('al', 'a</w>')
# Tokens lenght: 10340
# ==========
# Iter: 395
# Best pair: ('u’n', 'da</w>')
# Tokens lenght: 10341
# ==========
# Iter: 396
# Best pair: ('Sınav', '</w>')
# Tokens lenght: 10342
# ==========
# Iter: 397
# Best pair: ('at', 'ç')
# Tokens lenght: 10343
# ==========
# Iter: 398
# Best pair: ('mez', 'ar')
# Tokens lenght: 10344
# ==========
# Iter: 399
# Best pair: ('Zar', 'if')
# Tokens lenght: 10345
# ==========
# Iter: 400
# Best pair: ('buluş', 'tu.</w>')
# Tokens lenght: 10346
# ==========
# Iter: 401
# Best pair: ('Diy', 'anet</w>')
# Tokens lenght: 10347
# ==========
# Iter: 402
# Best pair: ('kurtar', 'ma</w>')
# Tokens lenght: 10348
# ==========
# Iter: 403
# Best pair: ('siy', 'ah</w>')
# Tokens lenght: 10349
# ==========
# Iter: 404
# Best pair: ('Suriye', "'nin</w>")
# Tokens lenght: 10350
# ==========
# Iter: 405
# Best pair: ('yakalan', 'an</w>')
# Tokens lenght: 10351
# ==========
# Iter: 406
# Best pair: ('ha', 'dis')
# Tokens lenght: 10352
# ==========
# Iter: 407
# Best pair: ('mür', 'ac')
# Tokens lenght: 10353
# ==========
# Iter: 408
# Best pair: ('Küt', 'ah')
# Tokens lenght: 10354
# ==========
# Iter: 409
# Best pair: ('bağ', 'lam')
# Tokens lenght: 10355
# ==========
# Iter: 410
# Best pair: ('day', 'alı</w>')
# Tokens lenght: 10356
# ==========
# Iter: 411
# Best pair: ('6', '8')
# Tokens lenght: 10357
# ==========
# Iter: 412
# Best pair: ('ik', 'te</w>')
# Tokens lenght: 10358
# ==========
# Iter: 413
# Best pair: ('Gül', ',</w>')
# Tokens lenght: 10359
# ==========
# Iter: 414
# Best pair: ('tı', 'yla</w>')
# Tokens lenght: 10360
# ==========
# Iter: 415
# Best pair: ('nokt', 'ası</w>')
# Tokens lenght: 10361
# ==========
# Iter: 416
# Best pair: ('aş', 'ı</w>')
# Tokens lenght: 10362
# ==========
# Iter: 417
# Best pair: ('Has', 'tal')
# Tokens lenght: 10363
# ==========
# Iter: 418
# Best pair: ('y', 'ek')
# Tokens lenght: 10364
# ==========
# Iter: 419
# Best pair: ('kadro', 'suna</w>')
# Tokens lenght: 10365
# ==========
# Iter: 420
# Best pair: ('Vol', 'kan</w>')
# Tokens lenght: 10366
# ==========
# Iter: 421
# Best pair: ('oyuncu', 'ları</w>')
# Tokens lenght: 10367
# ==========
# Iter: 422
# Best pair: ('sıf', 'ır')
# Tokens lenght: 10368
# ==========
# Iter: 423
# Best pair: ('sev', 'gi</w>')
# Tokens lenght: 10369
# ==========
# Iter: 424
# Best pair: ('Komutan', 'lığ')
# Tokens lenght: 10370
# ==========
# Iter: 425
# Best pair: ('bil', 'iyor</w>')
# Tokens lenght: 10371
# ==========
# Iter: 426
# Best pair: ('sanat', 'çı</w>')
# Tokens lenght: 10372
# ==========
# Iter: 427
# Best pair: ('Kür', 't</w>')
# Tokens lenght: 10373
# ==========
# Iter: 428
# Best pair: ('veril', 'diği</w>')
# Tokens lenght: 10374
# ==========
# Iter: 429
# Best pair: ('a', '”</w>')
# Tokens lenght: 10375
# ==========
# Iter: 430
# Best pair: ('kıl', 'ın')
# Tokens lenght: 10376
# ==========
# Iter: 431
# Best pair: ('Hat', 'ay</w>')
# Tokens lenght: 10377
# ==========
# Iter: 432
# Best pair: ('tarih', 'e</w>')
# Tokens lenght: 10378
# ==========
# Iter: 433
# Best pair: ('G', 'ar')
# Tokens lenght: 10379
# ==========
# Iter: 434
# Best pair: ('ihbar', 'ı</w>')
# Tokens lenght: 10380
# ==========
# Iter: 435
# Best pair: ('Hin', 't</w>')
# Tokens lenght: 10381
# ==========
# Iter: 436
# Best pair: ('D', '.')
# Tokens lenght: 10382
# ==========
# Iter: 437
# Best pair: ('mü', 'te')
# Tokens lenght: 10383
# ==========
# Iter: 438
# Best pair: ('seviy', 'esinde</w>')
# Tokens lenght: 10384
# ==========
# Iter: 439
# Best pair: ('suz', 'luk')
# Tokens lenght: 10385
# ==========
# Iter: 440
# Best pair: ('ver', 'me</w>')
# Tokens lenght: 10386
# ==========
# Iter: 441
# Best pair: ('biç', 'imde</w>')
# Tokens lenght: 10387
# ==========
# Iter: 442
# Best pair: ('geçir', 'ilen</w>')
# Tokens lenght: 10388
# ==========
# Iter: 443
# Best pair: ('İn', 'ter')
# Tokens lenght: 10389
# ==========
# Iter: 444
# Best pair: ('girişim', 'c')
# Tokens lenght: 10390
# ==========
# Iter: 445
# Best pair: ('kal', 'dığını</w>')
# Tokens lenght: 10391
# ==========
# Iter: 446
# Best pair: ('mesel', 'esi</w>')
# Tokens lenght: 10392
# ==========
# Iter: 447
# Best pair: ('iler', 'imizin</w>')
# Tokens lenght: 10393
# ==========
# Iter: 448
# Best pair: ('K', 'İŞ')
# Tokens lenght: 10394
# ==========
# Iter: 449
# Best pair: ('bl', 'ock')
# Tokens lenght: 10395
# ==========
# Iter: 450
# Best pair: ('r', 'on')
# Tokens lenght: 10396
# ==========
# Iter: 451
# Best pair: ('Er', 'dem</w>')
# Tokens lenght: 10397
# ==========
# Iter: 452
# Best pair: ('os', 'unu</w>')
# Tokens lenght: 10398
# ==========
# Iter: 453
# Best pair: ('m', 'ece</w>')
# Tokens lenght: 10399
# ==========
# Iter: 454
# Best pair: ('oğlu', '’nun</w>')
# Tokens lenght: 10400
# ==========
# Iter: 455
# Best pair: ('Terör', 'le</w>')
# Tokens lenght: 10401
# ==========
# Iter: 456
# Best pair: ('Ad', 'ay</w>')
# Tokens lenght: 10402
# ==========
# Iter: 457
# Best pair: ('Hastan', 'esine</w>')
# Tokens lenght: 10403
# ==========
# Iter: 458
# Best pair: ('bar', 'ek</w>')
# Tokens lenght: 10404
# ==========
# Iter: 459
# Best pair: ('S', 'K</w>')
# Tokens lenght: 10405
# ==========
# Iter: 460
# Best pair: ('çık', 'ıp</w>')
# Tokens lenght: 10406
# ==========
# Iter: 461
# Best pair: ('ık', 'lık</w>')
# Tokens lenght: 10407
# ==========
# Iter: 462
# Best pair: ('numar', 'alı</w>')
# Tokens lenght: 10408
# ==========
# Iter: 463
# Best pair: ('biz', 'den</w>')
# Tokens lenght: 10409
# ==========
# Iter: 464
# Best pair: ('iş', 'ten</w>')
# Tokens lenght: 10410
# ==========
# Iter: 465
# Best pair: ('tehlik', 'e</w>')
# Tokens lenght: 10411
# ==========
# Iter: 466
# Best pair: ('bilin', 'ç')
# Tokens lenght: 10412
# ==========
# Iter: 467
# Best pair: ('rö', 'port')
# Tokens lenght: 10413
# ==========
# Iter: 468
# Best pair: ('KOB', 'İ')
# Tokens lenght: 10414
# ==========
# Iter: 469
# Best pair: ('ver', 'ecek')
# Tokens lenght: 10415
# ==========
# Iter: 470
# Best pair: ('fik', 'ir')
# Tokens lenght: 10416
# ==========
# Iter: 471
# Best pair: ('2', ',5</w>')
# Tokens lenght: 10417
# ==========
# Iter: 472
# Best pair: ('UN', 'U</w>')
# Tokens lenght: 10418
# ==========
# Iter: 473
# Best pair: ('BAH', 'Ç')
# Tokens lenght: 10419
# ==========
# Iter: 474
# Best pair: ('5', '9</w>')
# Tokens lenght: 10420
# ==========
# Iter: 475
# Best pair: ('etkil', 'ey')
# Tokens lenght: 10421
# ==========
# Iter: 476
# Best pair: ('Mahkem', 'esi</w>')
# Tokens lenght: 10422
# ==========
# Iter: 477
# Best pair: ('k', 'ış')
# Tokens lenght: 10423
# ==========
# Iter: 478
# Best pair: ('iğ', 'in</w>')
# Tokens lenght: 10424
# ==========
# Iter: 479
# Best pair: ('bölg', 'esi</w>')
# Tokens lenght: 10425
# ==========
# Iter: 480
# Best pair: ('es', 'er</w>')
# Tokens lenght: 10426
# ==========
# Iter: 481
# Best pair: ('ist', 'in')
# Tokens lenght: 10427
# ==========
# Iter: 482
# Best pair: ('ver', 'imli</w>')
# Tokens lenght: 10428
# ==========
# Iter: 483
# Best pair: ('6', '1</w>')
# Tokens lenght: 10429
# ==========
# Iter: 484
# Best pair: ('gö', 'm')
# Tokens lenght: 10430
# ==========
# Iter: 485
# Best pair: ('fırsat', 'ı</w>')
# Tokens lenght: 10431
# ==========
# Iter: 486
# Best pair: ('dör', 'düncü</w>')
# Tokens lenght: 10432
# ==========
# Iter: 487
# Best pair: ('kal', 'b')
# Tokens lenght: 10433
# ==========
# Iter: 488
# Best pair: ('gerek', 'mektedir.</w>')
# Tokens lenght: 10434
# ==========
# Iter: 489
# Best pair: ('Kay', 'mak')
# Tokens lenght: 10435
# ==========
# Iter: 490
# Best pair: ('bulut', 'lu,</w>')
# Tokens lenght: 10436
# ==========
# Iter: 491
# Best pair: ('ik', 'ler</w>')
# Tokens lenght: 10437
# ==========
# Iter: 492
# Best pair: ('G', 'am')
# Tokens lenght: 10438
# ==========
# Iter: 493
# Best pair: ('part', 'il')
# Tokens lenght: 10439
# ==========
# Iter: 494
# Best pair: ('Antal', 'yaspor</w>')
# Tokens lenght: 10440
# ==========
# Iter: 495
# Best pair: ('hizmet', 'leri</w>')
# Tokens lenght: 10441
# ==========
# Iter: 496
# Best pair: ('vef', 'at</w>')
# Tokens lenght: 10442
# ==========
# Iter: 497
# Best pair: ('ek', 'te</w>')
# Tokens lenght: 10443
# ==========
# Iter: 498
# Best pair: ('başladı', 'k')
# Tokens lenght: 10444
# ==========
# Iter: 499
# Best pair: ('ç', 'ek</w>')
# Tokens lenght: 10445
# ==========
# Iter: 500
# Best pair: ('Göz', 'altına</w>')
# Tokens lenght: 10446
# ==========
# Iter: 501
# Best pair: ('lay', 'ık</w>')
# Tokens lenght: 10447
# ==========
# Iter: 502
# Best pair: ('um', '.</w>')
# Tokens lenght: 10448
# ==========
# Iter: 503
# Best pair: ('en', 'f')
# Tokens lenght: 10449
# ==========
# Iter: 504
# Best pair: ('misaf', 'ir')
# Tokens lenght: 10450
# ==========
# Iter: 505
# Best pair: ('Piy', 'as')
# Tokens lenght: 10451
# ==========
# Iter: 506
# Best pair: ('M', 'ES')
# Tokens lenght: 10452
# ==========
# Iter: 507
# Best pair: ('ülkemiz', 'e</w>')
# Tokens lenght: 10453
# ==========
# Iter: 508
# Best pair: ('din', 'am')
# Tokens lenght: 10454
# ==========
# Iter: 509
# Best pair: ('renk', 'li</w>')
# Tokens lenght: 10455
# ==========
# Iter: 510
# Best pair: ('böl', 'ün')
# Tokens lenght: 10456
# ==========
# Iter: 511
# Best pair: ('im', '”</w>')
# Tokens lenght: 10457
# ==========
# Iter: 512
# Best pair: ('mahk', 'um</w>')
# Tokens lenght: 10458
# ==========
# Iter: 513
# Best pair: ('karşıl', 'ığında</w>')
# Tokens lenght: 10459
# ==========
# Iter: 514
# Best pair: ('kaz', 'ada</w>')
# Tokens lenght: 10460
# ==========
# Iter: 515
# Best pair: ('aç', ',</w>')
# Tokens lenght: 10461
# ==========
# Iter: 516
# Best pair: ('sür', 'ülen</w>')
# Tokens lenght: 10462
# ==========
# Iter: 517
# Best pair: ('soruştur', 'ması</w>')
# Tokens lenght: 10463
# ==========
# Iter: 518
# Best pair: ('git', 'tik')
# Tokens lenght: 10464
# ==========
# Iter: 519
# Best pair: ('al', 'dığımız</w>')
# Tokens lenght: 10465
# ==========
# Iter: 520
# Best pair: ('V', 'İ')
# Tokens lenght: 10466
# ==========
# Iter: 521
# Best pair: ('Balıkes', 'ir</w>')
# Tokens lenght: 10467
# ==========
# Iter: 522
# Best pair: ('c', 'ak,</w>')
# Tokens lenght: 10468
# ==========
# Iter: 523
# Best pair: ('iş', 'ken')
# Tokens lenght: 10469
# ==========
# Iter: 524
# Best pair: ('Oyun', 'cu</w>')
# Tokens lenght: 10470
# ==========
# Iter: 525
# Best pair: ('ef', 'san')
# Tokens lenght: 10471
# ==========
# Iter: 526
# Best pair: ('FI', 'F')
# Tokens lenght: 10472
# ==========
# Iter: 527
# Best pair: ('n', 'ik</w>')
# Tokens lenght: 10473
# ==========
# Iter: 528
# Best pair: ('Adan', "a'da</w>")
# Tokens lenght: 10474
# ==========
# Iter: 529
# Best pair: ('netic', 'esinde</w>')
# Tokens lenght: 10475
# ==========
# Iter: 530
# Best pair: ('millet', 'imizin</w>')
# Tokens lenght: 10476
# ==========
# Iter: 531
# Best pair: ('güncellem', 'e</w>')
# Tokens lenght: 10477
# ==========
# Iter: 532
# Best pair: ('O', 'J')
# Tokens lenght: 10478
# ==========
# Iter: 533
# Best pair: ('H', 'AN')
# Tokens lenght: 10479
# ==========
# Iter: 534
# Best pair: ('mas', 'ında,</w>')
# Tokens lenght: 10480
# ==========
# Iter: 535
# Best pair: ('as', 'ı.</w>')
# Tokens lenght: 10481
# ==========
# Iter: 536
# Best pair: ('el', 'indeki</w>')
# Tokens lenght: 10482
# ==========
# Iter: 537
# Best pair: ('s', 'o')
# Tokens lenght: 10483
# ==========
# Iter: 538
# Best pair: ('ür', 'ünü</w>')
# Tokens lenght: 10484
# ==========
# Iter: 539
# Best pair: ('b', 'ey</w>')
# Tokens lenght: 10485
# ==========
# Iter: 540
# Best pair: ('dah', 'il')
# Tokens lenght: 10486
# ==========
# Iter: 541
# Best pair: ('giriş', 'imi</w>')
# Tokens lenght: 10487
# ==========
# Iter: 542
# Best pair: ('taraf', 'ta</w>')
# Tokens lenght: 10488
# ==========
# Iter: 543
# Best pair: ('Gazet', 'ec')
# Tokens lenght: 10489
# ==========
# Iter: 544
# Best pair: ('alı', 'ğı</w>')
# Tokens lenght: 10490
# ==========
# Iter: 545
# Best pair: ("'", 'DE</w>')
# Tokens lenght: 10491
# ==========
# Iter: 546
# Best pair: ('H', 'ız')
# Tokens lenght: 10492
# ==========
# Iter: 547
# Best pair: ('ikram', 'iy')
# Tokens lenght: 10493
# ==========
# Iter: 548
# Best pair: ('as', ',</w>')
# Tokens lenght: 10494
# ==========
# Iter: 549
# Best pair: ('Antal', "ya'da</w>")
# Tokens lenght: 10495
# ==========
# Iter: 550
# Best pair: ('ek', 'im</w>')
# Tokens lenght: 10496
# ==========
# Iter: 551
# Best pair: ('etti', '.')
# Tokens lenght: 10497
# ==========
# Iter: 552
# Best pair: ('sın', 'ız')
# Tokens lenght: 10498
# ==========
# Iter: 553
# Best pair: ('gol', 'e</w>')
# Tokens lenght: 10499
# ==========
# Iter: 554
# Best pair: ('met', 'in</w>')
# Tokens lenght: 10500
# ==========

# %%
len(tokens)

# %%
# write python dict to a file

output = open('tokens15000.pkl', 'wb')
pickle.dump(tokens, output)
output.close()
output = open('vocab15000.pkl', 'wb')
pickle.dump(vocab, output)
output.close()

# %% [markdown]
# ### Decoding the tokens
# Concatinate all the tokens together and get split where '</w>' is

# %% [markdown]
# ### Encoding a sequence
#
# 1. We list tokens from long to short
# 2. For each word, we iterate through all the tokens and check if each token is a substring of the word, if so, that token is one of the tokens in the word

# %%
def get_tokens_from_vocab(vocab):
    tokens_frequencies = collections.defaultdict(int)
    vocab_tokenization = {}
    for word, freq in vocab.items():
        word_tokens = word.split()
        for token in word_tokens:
            tokens_frequencies[token] += freq
        vocab_tokenization[''.join(word_tokens)] = word_tokens
    return tokens_frequencies, vocab_tokenization

def measure_token_length(token):
    if token[-4:] == '</w>':
        return len(token[:-4]) + 1
    else:
        return len(token)

def tokenize_word(string, sorted_tokens, unknown_token='</u>'):
    
    if string == '':
        return []
    if sorted_tokens == []:
        return [unknown_token]

    string_tokens = []
    for i in range(len(sorted_tokens)):
        token = sorted_tokens[i]
        token_reg = re.escape(token.replace('.', '[.]'))

        matched_positions = [(m.start(0), m.end(0)) for m in re.finditer(token_reg, string)]
        if len(matched_positions) == 0:
            continue
        substring_end_positions = [matched_position[0] for matched_position in matched_positions]

        substring_start_position = 0
        for substring_end_position in substring_end_positions:
            substring = string[substring_start_position:substring_end_position]
            string_tokens += tokenize_word(string=substring, sorted_tokens=sorted_tokens[i+1:], unknown_token=unknown_token)
            string_tokens += [token]
            substring_start_position = substring_end_position + len(token)
        remaining_substring = string[substring_start_position:]
        string_tokens += tokenize_word(string=remaining_substring, sorted_tokens=sorted_tokens[i+1:], unknown_token=unknown_token)
        break
    return string_tokens

# %%
tokens_frequencies, vocab_tokenization = get_tokens_from_vocab(vocab)

# %%
sorted_tokens_tuple = sorted(tokens_frequencies.items(), key=lambda item: (measure_token_length(item[0]), item[1]), reverse=True)
sorted_tokens = [token for (token,freq ) in sorted_tokens_tuple]

word_given = 'cumhurbaşkanımız</w>'
if word_given in vocab_tokenization:
    print('Tokenizin word: {} \n'.format(word_given))
    print(tokenize_word(string=word_given, sorted_tokens=sorted_tokens,unknown_token='</u>'))
else:
    print('Tokenizin unknown word: {} \n'.format(word_given))
    print(tokenize_word(string=word_given, sorted_tokens=sorted_tokens,unknown_token='</u>'))
# Out:
# Tokenizin word: cumhurbaşkanımız</w>
#
# ['cumhur', 'başkan', 'ımız</w>']
